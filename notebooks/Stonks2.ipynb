# %%
import pandas as pd

# Load dataset
file_path = "train_data.csv"  # Replace with actual filename
df = pd.read_csv(file_path, parse_dates=["date"])

# List of 10 stocks to keep
selected_stocks = ["AAPL", "MSFT", "TSLA", "AMZN", "GOOGL", "NVDA", "META", "JPM", "V", "UNH"]

# Filter only required stocks
df = df[df["tic"].isin(selected_stocks)]

# Pivot table to have stock symbols as columns and dates as index
df_pivot = df.pivot(index="date", columns="tic", values="close")

# Sort by date
df_pivot = df_pivot.sort_index()

# Save to CSV
df_pivot.to_csv("stock_prices.csv")

print("Processed data saved as stock_prices.csv")
# Out:
# Processed data saved as stock_prices.csv

# %%
d = pd.read_csv("stock_prices.csv")
d.head()
# Out:
#          date      AAPL        JPM       MSFT        UNH          V
# 0  2009-01-02  2.758536  22.201174  15.200124  22.703112  12.079281
# 1  2009-01-05  2.874956  20.714014  15.342181  22.332815  12.165176
# 2  2009-01-06  2.827537  21.160160  15.521620  21.806171  13.021852
# 3  2009-01-07  2.766438  19.892542  14.587044  21.641588  12.739308
# 4  2009-01-08  2.817810  19.276423  15.043111  21.978975  12.603688

# %%
d.shape
# Out:
# (2893, 6)

# %% [markdown]
# #DDPG Stock Allocation

# %%
# !pip install stable-baselines3

# %%
# !pip install --upgrade stable-baselines3 gym

# %%
# !pip install shimmy

# %%
import numpy as np
import gym
import gym.spaces
from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
class AllocationEnv(gym.Env):
    def __init__(self, stock_data, initial_balance=10000):
        super(AllocationEnv, self).__init__()
        self.stock_data = stock_data  # DataFrame with historical prices
        self.initial_balance = initial_balance
        self.current_step = 0
        self.balance = initial_balance
        self.allocation = np.zeros(len(stock_data.columns))  # Fund allocation percentages

        # Action space: percentage allocation for each stock
        self.action_space = gym.spaces.Box(low=0, high=1, shape=(len(stock_data.columns),), dtype=np.float32)
        self.observation_space = gym.spaces.Box(low=0, high=np.inf, shape=(len(stock_data.columns) + 1,), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        self.balance = self.initial_balance
        self.allocation = np.zeros(len(self.stock_data.columns))
        return self._next_observation()

    def _next_observation(self):
        prices = self.stock_data.iloc[self.current_step].values
        return np.append(prices, self.balance)

    def step(self, action):
        """Executes allocation based on the action and calculates portfolio value."""
        action = np.clip(action, 0, 1)  # Ensure valid allocations
        action /= np.sum(action)  # Normalize to sum to 1

        prices = self.stock_data.iloc[self.current_step].values
        portfolio_value = self.balance * action
        self.allocation = portfolio_value / prices  # Shares allocated per stock

        self.current_step += 1
        done = self.current_step >= len(self.stock_data) - 1
        reward = np.sum(self.allocation * prices)  # Portfolio value as reward
        return self._next_observation(), reward, done, {}

# %%
import pandas as pd
stock_data = pd.read_csv("stock_prices.csv", index_col=0)  # Format: Columns = Stocks, Rows = Dates

# Create environment
env = DummyVecEnv([lambda: AllocationEnv(stock_data)])

# Set up DDPG with noise for exploration
action_noise = NormalActionNoise(mean=np.zeros(len(stock_data.columns)), sigma=0.1 * np.ones(len(stock_data.columns)))
model = DDPG("MlpPolicy", env, action_noise=action_noise, verbose=1)

# Train the model
model.learn(total_timesteps=100000)

# Save trained model
model.save("ddpg_allocation_model")
# Out:
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 36        |
# |    time_elapsed    | 319       |
# |    total_timesteps | 11568     |
# | train/             |           |
# |    actor_loss      | -4.31e+05 |
# |    critic_loss     | 1.66e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11467     |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 36        |
# |    time_elapsed    | 637       |
# |    total_timesteps | 23136     |
# | train/             |           |
# |    actor_loss      | -6.78e+05 |
# |    critic_loss     | 8.34e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23035     |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 36        |
# |    time_elapsed    | 958       |
# |    total_timesteps | 34704     |
# | train/             |           |
# |    actor_loss      | -8.07e+05 |
# |    critic_loss     | 5.05e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34603     |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 36        |
# |    time_elapsed    | 1277      |
# |    total_timesteps | 46272     |
# | train/             |           |
# |    actor_loss      | -8.86e+05 |
# |    critic_loss     | 1.32e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 46171     |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 36        |
# |    time_elapsed    | 1596      |
# |    total_timesteps | 57840     |
# | train/             |           |
# |    actor_loss      | -9.01e+05 |
# |    critic_loss     | 3.27e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 57739     |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 36        |
# |    time_elapsed    | 1916      |
# |    total_timesteps | 69408     |
# | train/             |           |
# |    actor_loss      | -9.36e+05 |
# |    critic_loss     | 4.34e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 69307     |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 36        |
# |    time_elapsed    | 2239      |
# |    total_timesteps | 80976     |
# | train/             |           |
# |    actor_loss      | -9.44e+05 |
# |    critic_loss     | 4.9e+07   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 80875     |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 36        |
# |    time_elapsed    | 2568      |
# |    total_timesteps | 92544     |
# | train/             |           |
# |    actor_loss      | -9.66e+05 |
# |    critic_loss     | 4.08e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 92443     |
# ----------------------------------

# %% [markdown]
# #PPO Stock Buy/Sell Signals

# %%
from stable_baselines3 import PPO

# %%
class TradingEnv(gym.Env):
    def __init__(self, stock_data, initial_balance=10000):
        super(TradingEnv, self).__init__()
        self.stock_data = stock_data  # DataFrame with 'Close' prices per stock
        self.initial_balance = initial_balance
        self.current_step = 0
        self.balance = initial_balance
        self.holdings = np.zeros(len(stock_data.columns))  # Stocks held

        # Define action & observation spaces
        self.action_space = gym.spaces.Box(low=-1, high=1, shape=(len(stock_data.columns),), dtype=np.float32)  # Buy (-1) or Sell (+1)
        self.observation_space = gym.spaces.Box(low=0, high=np.inf, shape=(len(stock_data.columns) + 1,), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        self.balance = self.initial_balance
        self.holdings = np.zeros(len(self.stock_data.columns))
        return self._next_observation()

    def _next_observation(self):
        prices = self.stock_data.iloc[self.current_step].values
        return np.append(prices, self.balance)

    def step(self, action):
        """Executes trades based on the action and updates the portfolio."""
        prices = self.stock_data.iloc[self.current_step].values
        for i in range(len(self.holdings)):
            if action[i] > 0:  # Buy
                num_shares = (self.balance * action[i]) / prices[i]
                self.holdings[i] += num_shares
                self.balance -= num_shares * prices[i]
            elif action[i] < 0:  # Sell
                num_shares = min(abs(action[i]) * self.holdings[i], self.holdings[i])
                self.balance += num_shares * prices[i]
                self.holdings[i] -= num_shares

        self.current_step += 1
        done = self.current_step >= len(self.stock_data) - 1
        reward = self.balance + np.sum(self.holdings * prices)  # Portfolio value
        return self._next_observation(), reward, done, {}

# %%
stock_data = pd.read_csv("stock_prices.csv", index_col=0)  # Format: Columns = Stocks, Rows = Dates

# Create environment
env = DummyVecEnv([lambda: TradingEnv(stock_data)])

# Train PPO model
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=100000)

# Save trained model
model.save("ppo_trading_model")
# Out:
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 826  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 720           |
# |    iterations           | 2             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 2.0800799e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.52e+11      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -9.05e-05     |
# |    std                  | 1             |
# |    value_loss           | 2.77e+11      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 676           |
# |    iterations           | 3             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 2.0020525e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.92e+11      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -1.81e-05     |
# |    std                  | 1             |
# |    value_loss           | 8.16e+11      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 641          |
# |    iterations           | 4            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 9.582145e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.43e+11     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -5.88e-05    |
# |    std                  | 1            |
# |    value_loss           | 5.27e+11     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 645           |
# |    iterations           | 5             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 4.6007335e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.54e+11      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -3.77e-05     |
# |    std                  | 1             |
# |    value_loss           | 3.28e+11      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 641           |
# |    iterations           | 6             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 7.4575655e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.88e+11      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -5.21e-05     |
# |    std                  | 1             |
# |    value_loss           | 3.77e+11      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 628          |
# |    iterations           | 7            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 2.871093e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.34e+11     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -2.73e-05    |
# |    std                  | 1            |
# |    value_loss           | 7.47e+11     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 625           |
# |    iterations           | 8             |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 1.5854312e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.82e+10      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -7.37e-05     |
# |    std                  | 1             |
# |    value_loss           | 2.51e+11      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 9            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 1.880253e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+11     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -6.11e-05    |
# |    std                  | 1            |
# |    value_loss           | 1.48e+11     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 627          |
# |    iterations           | 10           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 5.841139e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.75e+11     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -4.05e-05    |
# |    std                  | 1            |
# |    value_loss           | 3.58e+11     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 609          |
# |    iterations           | 11           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 9.924406e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.76e+11     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -1.19e-05    |
# |    std                  | 1            |
# |    value_loss           | 9.7e+11      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 613           |
# |    iterations           | 12            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 3.6132406e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.7e+11       |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -3.25e-05     |
# |    std                  | 1             |
# |    value_loss           | 5.68e+11      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 616           |
# |    iterations           | 13            |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 1.5256228e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.27e+11      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -1.67e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.79e+12      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 616           |
# |    iterations           | 14            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 4.4467743e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.11e+11      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -3.81e-05     |
# |    std                  | 1             |
# |    value_loss           | 9.27e+11      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 611          |
# |    iterations           | 15           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 2.860499e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.15e+10     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -9.76e-05    |
# |    std                  | 1            |
# |    value_loss           | 1.13e+11     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 609          |
# |    iterations           | 16           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 1.159322e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.05e+10     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -4.95e-05    |
# |    std                  | 1            |
# |    value_loss           | 1.51e+11     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 607           |
# |    iterations           | 17            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 3.9328006e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.55e+11      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -2.77e-05     |
# |    std                  | 1             |
# |    value_loss           | 7.05e+11      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 597           |
# |    iterations           | 18            |
# |    time_elapsed         | 61            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 1.4324905e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.2e+12       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -1.97e-05     |
# |    std                  | 1             |
# |    value_loss           | 2.27e+12      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 599          |
# |    iterations           | 19           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 1.254899e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.05e+11     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -6.99e-05    |
# |    std                  | 1            |
# |    value_loss           | 2.07e+11     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 601           |
# |    iterations           | 20            |
# |    time_elapsed         | 68            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 1.9103754e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.1e+11       |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -1.84e-05     |
# |    std                  | 1             |
# |    value_loss           | 6.25e+11      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 601           |
# |    iterations           | 21            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 1.9391882e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9e+11         |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -2.87e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.81e+12      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 599           |
# |    iterations           | 22            |
# |    time_elapsed         | 75            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 1.7968705e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.7e+11       |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -1.79e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.17e+12      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 600           |
# |    iterations           | 23            |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 1.8152059e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.63e+11      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -1.62e-05     |
# |    std                  | 1             |
# |    value_loss           | 8.26e+11      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 602          |
# |    iterations           | 24           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 2.544257e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.49e+11     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -2.83e-05    |
# |    std                  | 1            |
# |    value_loss           | 1.21e+12     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 600           |
# |    iterations           | 25            |
# |    time_elapsed         | 85            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 2.8667273e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.85e+11      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -2.74e-05     |
# |    std                  | 1             |
# |    value_loss           | 9.38e+11      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 600          |
# |    iterations           | 26           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 4.909234e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.09e+11     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -2.92e-05    |
# |    std                  | 1            |
# |    value_loss           | 2.2e+11      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 602           |
# |    iterations           | 27            |
# |    time_elapsed         | 91            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 2.5102054e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.93e+11      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -2.48e-05     |
# |    std                  | 1             |
# |    value_loss           | 7e+11         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 604           |
# |    iterations           | 28            |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 1.4566467e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.5e+11       |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -1.7e-05      |
# |    std                  | 1             |
# |    value_loss           | 1.14e+12      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 601          |
# |    iterations           | 29           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 1.519802e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.58e+11     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -1.34e-05    |
# |    std                  | 1            |
# |    value_loss           | 3.04e+11     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 603           |
# |    iterations           | 30            |
# |    time_elapsed         | 101           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 3.8841972e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.8e+11       |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -3.16e-05     |
# |    std                  | 1             |
# |    value_loss           | 4.57e+11      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 605           |
# |    iterations           | 31            |
# |    time_elapsed         | 104           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 1.6775448e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.19e+11      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -1.63e-05     |
# |    std                  | 1             |
# |    value_loss           | 8.88e+11      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 32           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 3.853347e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.13e+12     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -1.09e-05    |
# |    std                  | 1            |
# |    value_loss           | 4.55e+12     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 601          |
# |    iterations           | 33           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 4.534959e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.27e+11     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -3.61e-05    |
# |    std                  | 1            |
# |    value_loss           | 1.28e+12     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 601           |
# |    iterations           | 34            |
# |    time_elapsed         | 115           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 4.4773333e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.31e+11      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -4.11e-05     |
# |    std                  | 1             |
# |    value_loss           | 8.5e+11       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 601           |
# |    iterations           | 35            |
# |    time_elapsed         | 119           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 1.5317346e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.08e+11      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -2.25e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.09e+12      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 598          |
# |    iterations           | 36           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 1.527369e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.27e+11     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -1.43e-05    |
# |    std                  | 1            |
# |    value_loss           | 4.32e+11     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 599          |
# |    iterations           | 37           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 6.678165e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.23e+11     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -4.36e-05    |
# |    std                  | 1            |
# |    value_loss           | 8.18e+11     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 600          |
# |    iterations           | 38           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 7.706112e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2e+11        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -5.02e-05    |
# |    std                  | 1            |
# |    value_loss           | 4.28e+11     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 601           |
# |    iterations           | 39            |
# |    time_elapsed         | 132           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 8.4540807e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.45e+11      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -5.82e-05     |
# |    std                  | 1             |
# |    value_loss           | 4.72e+11      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 599           |
# |    iterations           | 40            |
# |    time_elapsed         | 136           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 1.5160476e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.28e+11      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -7.27e-05     |
# |    std                  | 1             |
# |    value_loss           | 2.57e+11      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 600           |
# |    iterations           | 41            |
# |    time_elapsed         | 139           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 2.0733569e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.02e+11      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -1.82e-05     |
# |    std                  | 1             |
# |    value_loss           | 7.42e+11      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 601          |
# |    iterations           | 42           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 8.221832e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73e+12     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -1.43e-05    |
# |    std                  | 1            |
# |    value_loss           | 3.08e+12     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 600          |
# |    iterations           | 43           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 8.380157e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+11     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -4.77e-05    |
# |    std                  | 1            |
# |    value_loss           | 3.25e+11     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 599          |
# |    iterations           | 44           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 9.852811e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.52e+11     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -6.56e-05    |
# |    std                  | 1            |
# |    value_loss           | 7.88e+11     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 600           |
# |    iterations           | 45            |
# |    time_elapsed         | 153           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 5.8920705e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.6e+11       |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -4.11e-05     |
# |    std                  | 1             |
# |    value_loss           | 5.71e+11      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 601           |
# |    iterations           | 46            |
# |    time_elapsed         | 156           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 1.8248102e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.97e+11      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -2.18e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.36e+12      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 600           |
# |    iterations           | 47            |
# |    time_elapsed         | 160           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 3.7573045e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.69e+11      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -5.1e-06      |
# |    std                  | 1             |
# |    value_loss           | 1.32e+12      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 600          |
# |    iterations           | 48           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 4.475005e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.78e+11     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -3.84e-05    |
# |    std                  | 1            |
# |    value_loss           | 1.15e+12     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 599           |
# |    iterations           | 49            |
# |    time_elapsed         | 167           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 4.3062028e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.74e+11      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -3.75e-05     |
# |    std                  | 1             |
# |    value_loss           | 4.04e+11      |
# -------------------------------------------
